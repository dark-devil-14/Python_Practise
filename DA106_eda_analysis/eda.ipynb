# %%
# %pip install seaborn matplotlib

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp314-cp314-macosx_10_13_x86_64.whl.metadata (52 kB)
# Collecting numpy!=1.24.0,>=1.20 (from seaborn)
#   Using cached numpy-2.4.2-cp314-cp314-macosx_10_15_x86_64.whl.metadata (6.6 kB)
# Collecting pandas>=1.2 (from seaborn)
#   Using cached pandas-3.0.1-cp314-cp314-macosx_10_15_x86_64.whl.metadata (79 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.1-cp314-cp314-macosx_10_15_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp314-cp314-macosx_10_13_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/rajuram/Documents/Python_Practise/venv/lib/python3.14/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.1.1-cp314-cp314-macosx_10_15_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rajuram/Documents/Python_Practise/venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/rajuram/Documents/Python_Practise/venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.8-cp314-cp314-macosx_10_13_x86_64.whl (8.3 MB)
# Using cached contourpy-1.3.3-cp314-cp314-macosx_10_13_x86_64.whl (292 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp314-cp314-macosx_10_15_x86_64.whl (2.4 MB)
# Using cached kiwisolver-1.4.9-cp314-cp314-macosx_10_13_x86_64.whl (66 kB)
# Using cached numpy-2.4.2-cp314-cp314-macosx_10_15_x86_64.whl (16.7 MB)
# Using cached pandas-3.0.1-cp314-cp314-macosx_10_15_x86_64.whl (10.3 MB)
# Using cached pillow-12.1.1-cp314-cp314-macosx_10_15_x86_64.whl (5.3 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [seaborn]9/10 [seaborn]ib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 numpy-2.4.2 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2 seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# load iris dataset

df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Histrogram

plt.figure(figsize =(9,4))
sns.histplot(df['sepal_length'], bins=30)
plt.title("Histogram of Sepal Length")
plt.show()

# %%
#Densitry Plot

plt.figure(figsize=(6,4))
sns.kdeplot(df['sepal_length'])
plt.title("Density Plot of Sepeal Length")
plt.show()

# %%
#Densitry Plot

plt.figure(figsize=(6,4))
sns.kdeplot(df['sepal_length'])
sns.rugplot(df['sepal_length'])
plt.title("Density + RUG Plot of Sepeal Length")
plt.show()

# %%
# BOX PLOT

plt.figure(figsize=(7,6))
sns.boxplot(x= 'species', y='sepal_length', data=df)
plt.title("BOX PLOT of Speal Length")
plt.show()

# %%
#Co-relation (head_map)

plt.figure(figsize=(10,5))
sns.heatmap(df.iloc[:,0:4].corr(), annot=True, cmap='coolwarm')
plt.title("Head Map")
plt.show()

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
