# %% [markdown]
# <h3> Function and Recursions</h3>
#
#         A function is a block of code which only runs when it is called.
#
#         A function can return data as a result.
#
#         A function helps avoiding code repetition.
#
# In Python, a function is defined using the **def** keyword, followed by a function name and parentheses
#
#
#     A function name must start with a letter or underscore
#     A function name can only contain letters, numbers, and underscores
#     Function names are case-sensitive (myFunction and myfunction are different)

# %% [markdown]
# <h3> Return Values </h3>
#
#     Functions can send data back to the code that called them using the return statement.
#
#     When a function reaches a return statement, it stops executing and sends the result back:
#
#     If a function doesn't have a return statement, it returns None by default.
#
#     The pass Statement
#
# Function definitions cannot be empty. If you need to create a function placeholder without any code, use the pass statement:

# %%
#Example of the function 

def avg(): #function defination
    a = int(input("Enter Your Number: "))
    b = int(input("Enter Your Number: "))
    c = int(input("Enter Your Number: "))

    average = (a+b+c)/3
    print(average)

num = int(input("Enter the total Student: "))

for i in range(num):
    avg() #function call
# Out:
# 66.66666666666667
# 155.66666666666666
# 33.666666666666664
# 125.66666666666667

# %%
# Return Values and The pass Statement
# You can use the returned value directly


def pass_statement(): #Function definitions cannot be empty
    pass # if you need to create a function placeholder without any code, use pass

def get_greeting():
    return "Hello from a function!! Nice to meet you"

message = get_greeting() #object is assigned to mesage
pass_statement() # does nothing

message
# Out:
# 'Hello from a function!! Nice to meet you'

# %% [markdown]
# <h3>Arguments</h3>
#
#     Information can be passed into functions as arguments.
#
#     Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.
#
#     The following example has a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full name:

# %%
#   Function with argument
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")
# Out:
# Emil Refsnes
# Tobias Refsnes
# Linus Refsnes

# %%
def goodDay(name, ending):
    print("Good Day "+ name +", " + ending)



goodDay("Rajuram", "Thank You")
goodDay("Eami" , "Thank You")
goodDay("Robin", "Thank You")
# Out:
# Good Day Rajuram, Thank You
# Good Day Eami, Thank You
# Good Day Robin, Thank You

# %% [markdown]
# <h3>From a function's perspective: </h3>
#
# A parameter is the variable listed inside the parentheses in the function definition.
#
# An argument is the actual value that is sent to the function when it is called.

# %%
# From a function's perspective:

def my_function(name): # name is a parameter
  print("Hello", name)

my_function("Emil") # "Emil" is an argument
# Out:
# Hello Emil

# %% [markdown]
# # Recursion
#
#     Recursion is when a function calls itself.
#
#     Recursion is a common mathematical and programming concept. It means that a function calls itself. This has the benefit of meaning that you can loop through data to reach a result.

# %%
"""
factorial(1) = 1
factorial(2) = 2 X 1
factorial(3) = 3 X 2 X 1
factorial(4) = 4 X 3 X 2 X 1
factorial(5) = 5 X 4 X 3 X 2 X 1
factorial(6) = 6 X 5 X 4 X 3 X 2 X 1

factorial(n) = n X n-1 X .......... 1

factorial(n) = n X factorial(n-1)

"""
n = int(input("Enter a nunber: "))

def factorial(n):
    if(n==1 or n ==0): #base condition
        return 1
    return n * factorial(n-1)

print(f"The factorial of the {n} is {factorial(n)}")
# Out:
# The factorial of the 44 is 2658271574788448768043625811014615890319638528000000000

# %% [markdown]
# # Practise Problems
#
#     1.Write a program to find the greatest of 3 numbers

# %%
def greatest(a,b,c):
    if(a>b and a>c):
        return a
    elif(b>a and b>c):
        return b
    elif(c>a and c>b):
        return c

a = 32
b = 22 
c = 121 

print(greatest(a,b,c))
# Out:
# 121

# %% [markdown]
#     2. Write a python programming using function to convert celsius to fahrenhiet

# %%
# c/5 = (f-32)/9

def f_to_c(f):
    return  5*(f-32)/9

f = int(input("Enter the temp in F: "))

print(round(f_to_c(f),2)," C")
# Out:
# -5.0  C

# %% [markdown]
#     3. Write a recursive function to calculate 1st n natural number

# %%
"""
SUM(1) = 1
SUM(2) = 1+2
SUM(3) = 1+2+3
SUM(4) = 1+2+3+4


sum(N) = 1 + 2 + 3 + ......sum(N-1) +  N
SUM(N) = sum(n-1) + n
"""

def sum(n):
    if(n==1):
        return 1
    return sum(n-1) + n

print(sum(4))
# Out:
# 10

# %% [markdown]
#     4. write a python programm to print first n lines of the follow patter :
#     ***
#     **
#     * for n = 3

# %%
def rec(n):
    if(n==0):
        return
    print("*" * n)
    rec(n-1)

rec(3)
# Out:
# ***
# **
# *
